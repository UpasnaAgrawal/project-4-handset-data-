# %% [markdown]
# Data connect with Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Data Collection:#Load the dataset using libraries like Pandas or Numpy.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path ='/content/Processed_Flipdata - Processed_Flipdata.csv'
dataset = pd.read_csv(file_path)

# %%
dataset
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 0             0        Infinix SMART 7     Night Black      64    4      6000
# 1             1        Infinix SMART 7      Azure Blue      64    4      6000
# 2             2           MOTOROLA G32    Mineral Gray     128    8      5000
# 3             3               POCO C50      Royal Blue      32    2      5000
# 4             4        Infinix HOT 30i        Marigold     128    8      5000
# ..          ...                    ...             ...     ...  ...       ...
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
# ...

# %%
# to check initially top 5 data
dataset.head()
# Out:
#    Unnamed: 0            Model        Colour  Memory  RAM  Battery_  \
# 0           0  Infinix SMART 7   Night Black      64    4      6000
# 1           1  Infinix SMART 7    Azure Blue      64    4      6000
# 2           2     MOTOROLA G32  Mineral Gray     128    8      5000
# 3           3         POCO C50    Royal Blue      32    2      5000
# 4           4  Infinix HOT 30i      Marigold     128    8      5000
#
#   Rear Camera Front Camera  AI Lens  Mobile Height  \
# 0        13MP          5MP        1          16.76
# 1        13MP          5MP        1          16.76
# 2        50MP         16MP        0          16.64
# 3         8MP          5MP        0          16.56
# 4        50MP          5MP        1          16.76
#
#                    Processor_   Prize
# 0  Unisoc Spreadtrum SC9863A1   7,299
# 1  Unisoc Spreadtrum SC9863A1   7,299
# 2     Qualcomm Snapdragon 680  11,999
# 3          Mediatek Helio A22   5,649
# 4                         G37   8,999

# %%
# to check initially last 5 data

dataset.tail()
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
#     Rear Camera Front Camera  AI Lens  Mobile Height  \
# 536        50MP         12MP        0          15.49
# 537         5MP          2MP        0          12.70
# 538        50MP          8MP        0          16.76
# 539        50MP         32MP        0          16.26
# 540        50MP          8MP        0          16.66
#
#                       Processor_   Prize
# 536  Qualcomm Snapdragon 8 Gen 2  79,999
# 537                    Octa Core   5,998
# 538           MediaTek Helio G35   9,990
# ...

# %%
# to check columns names

dataset.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Colour', 'Memory', 'RAM', 'Battery_',
#        'Rear Camera', 'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_',
#        'Prize'],
#       dtype='object')

# %%
# to check information about the dataset

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     541 non-null    int64
#  1   Model          541 non-null    object
#  2   Colour         541 non-null    object
#  3   Memory         541 non-null    int64
#  4   RAM            541 non-null    int64
#  5   Battery_       541 non-null    int64
#  6   Rear Camera    541 non-null    object
#  7   Front Camera   541 non-null    object
#  8   AI Lens        541 non-null    int64
#  9   Mobile Height  541 non-null    float64
#  10  Processor_     541 non-null    object
#  11  Prize          541 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 50.8+ KB

# %%
# to check types of dataset

dataset.dtypes
# Out:
# Unnamed: 0         int64
# Model             object
# Colour            object
# Memory             int64
# RAM                int64
# Battery_           int64
# Rear Camera       object
# Front Camera      object
# AI Lens            int64
# Mobile Height    float64
# Processor_        object
# Prize             object
# dtype: object

# %%
# to check description of dataset

dataset.describe()
# Out:
#        Unnamed: 0      Memory         RAM     Battery_     AI Lens  \
# count  541.000000  541.000000  541.000000   541.000000  541.000000
# mean   289.711645  110.550832    5.397412  4871.587800    0.062847
# std    182.359185   60.600694    1.984923   780.148862    0.242911
# min      0.000000   16.000000    2.000000   800.000000    0.000000
# 25%    135.000000   64.000000    4.000000  5000.000000    0.000000
# 50%    273.000000  128.000000    6.000000  5000.000000    0.000000
# 75%    434.000000  128.000000    8.000000  5000.000000    0.000000
# max    642.000000  256.000000    8.000000  7000.000000    1.000000
#
#        Mobile Height
# count     541.000000
# mean       16.431201
# std         2.523553
# min         4.500000
# 25%        16.510000
# 50%        16.710000
# 75%        16.940000
# max        41.940000

# %% [markdown]
# For the Above statitics summary:
# * Memory ranges from 0 to 642 GB, with a mean of 290 GB, suggesting the dataset includes devices with a wide range of storage capacities.
# * RAM ranges from 16 to 256 GB, with common values being 64 GB and 128 GB.
# * Battery_ capacity ranges from 800 to 7000 mAh, with a mean of 4872 mAh.
# * AI Lens has values between 0 and 1, indicating it might be a binary feature.
# *Mobile Height ranges widely from 4.5 to 41.94 (possibly cm).

# %%
# to check null values of dataset

dataset.isnull().sum()
# Out:
# Unnamed: 0       0
# Model            0
# Colour           0
# Memory           0
# RAM              0
# Battery_         0
# Rear Camera      0
# Front Camera     0
# AI Lens          0
# Mobile Height    0
# Processor_       0
# Prize            0
# dtype: int64

# %%
# to check the unique value in one feature
dataset["Model"].unique()
# Out:
# array(['Infinix SMART 7', 'MOTOROLA G32', 'POCO C50', 'Infinix HOT 30i',
#        'REDMI 10', 'SAMSUNG Galaxy F13', 'SAMSUNG Galaxy F04', 'POCO C51',
#        'MOTOROLA e13', 'vivo T2x 5G', 'Infinix Smart 7 HD', 'REDMI A1+',
#        'POCO C55', 'MOTOROLA g13', 'POCO M4 5G', 'MOTOROLA e32',
#        'vivo T2 5G', 'MOTOROLA G62 5G', 'POCO M5', 'realme C33 2023',
#        'SAMSUNG Galaxy F14 5G', 'MOTOROLA g73 5G', 'realme C30',
#        'POCO X5 5G', 'POCO M4 Pro', 'REDMI 11 Prime', 'realme C55',
#        'realme 10 Pro 5G', 'Micromax IN 2C', 'POCO M4 Pro 5G',
#        'realme Narzo 30 Pro 5G', 'micromax 2', 'Infinix Note 12 Pro 5G',
#        'SAMSUNG Galaxy F23 5G', 'micromax', 'MOTOROLA Edge 40',
#        'micromax 1', 'realme Narzo 30', 'Infinix NOTE 12i', 'realme 10',
#        'realme 8i', 'Micromax 3', 'Google Pixel 6a', 'Infinix HOT 20 5G',
#        'realme GT 2', 'REDMI Note 12', 'REDMI Note 12 5G', 'micromax 3',
#        'SAMSUNG Galaxy M04', 'REDMI K50i 5G', 'MOTOROLA e40',
# ...

# %%
# Convert 'Prize' column to string type before using .str accessor

dataset['Prize'] = dataset['Prize'].astype(str).str.replace(',', '').astype(float)
dataset['Prize']
# Out:
# 0       7299.0
# 1       7299.0
# 2      11999.0
# 3       5649.0
# 4       8999.0
#         ...
# 536    79999.0
# 537     5998.0
# 538     9990.0
# 539    38999.0
# 540    15999.0
# Name: Prize, Length: 541, dtype: float64

# %% [markdown]
# Datatype of prize is categorical and columns was store in string likely due to the presence of commas we are doing due to preparating data for machine learning.comma removal  the str replace method remove commas from str value to clean the numerical value

# %%
dataset['Prize'].sort_values()
# Out:
# 246      920.0
# 247      920.0
# 250     1199.0
# 118     1299.0
# 155     1299.0
#         ...
# 426    55999.0
# 536    79999.0
# 525    80999.0
# 520    80999.0
# 493    80999.0
# Name: Prize, Length: 541, dtype: float64

# %%
dataset['Front Camera'] = dataset['Front Camera'].astype(str).str.replace('MP', '').astype(float)
dataset['Rear Camera'] = dataset['Rear Camera'].astype(str).str.replace('MP', '').astype(float)

# %% [markdown]
# We have to change the data type of front camara, rear camera to convert it in numarical (float) format.
#
#
# Same we have found front camara and rear camra in objective dtype because its "MP" postfix So we use as type function to change dtypes of both by replace MP by empty

# %%
#Data Cleaning:
#to check null values of dataset

dataset.isnull().sum()
# Out:
# Unnamed: 0       0
# Model            0
# Colour           0
# Memory           0
# RAM              0
# Battery_         0
# Rear Camera      0
# Front Camera     0
# AI Lens          0
# Mobile Height    0
# Processor_       0
# Prize            0
# dtype: int64

# %% [markdown]
# There is no null value found in dataset

# %%
dataset.dtypes
# Out:
# Unnamed: 0         int64
# Model             object
# Colour            object
# Memory             int64
# RAM                int64
# Battery_           int64
# Rear Camera      float64
# Front Camera     float64
# AI Lens            int64
# Mobile Height    float64
# Processor_        object
# Prize            float64
# dtype: object

# %% [markdown]
# We get all data type in int and float apart from color, model and processor are objective data type

# %%
# check duplicacy
dataset.duplicated().sum()
# Out:
# 0

# %%
duplicates = dataset[dataset.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Model, Colour, Memory, RAM, Battery_, Rear Camera, Front Camera, AI Lens, Mobile Height, Processor_, Prize]
# Index: []

# %%
# remove duplicate values
dataset= dataset.drop_duplicates()
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Drop "unnamed"columns because it have only srial no and will not affected on data

# %%
dataset = dataset.drop(['Unnamed: 0'], axis=1, errors='ignore')

# to checking unnamed column is remove or not
dataset.head(2)
# Out:
#              Model       Colour  Memory  RAM  Battery_  Rear Camera  \
# 0  Infinix SMART 7  Night Black      64    4      6000         13.0
# 1  Infinix SMART 7   Azure Blue      64    4      6000         13.0
#
#    Front Camera  AI Lens  Mobile Height                  Processor_   Prize
# 0           5.0        1          16.76  Unisoc Spreadtrum SC9863A1  7299.0
# 1           5.0        1          16.76  Unisoc Spreadtrum SC9863A1  7299.0

# %%
# Separate numeric and categorical columns
categorical_columns = dataset.select_dtypes(include=['object', 'category', 'string']).columns

# Display categorical columns
print("Categorical Columns:")
print(dataset[categorical_columns])
# Out:
# Categorical Columns:
#                      Model          Colour                   Processor_
# 0          Infinix SMART 7     Night Black   Unisoc Spreadtrum SC9863A1
# 1          Infinix SMART 7      Azure Blue   Unisoc Spreadtrum SC9863A1
# 2             MOTOROLA G32    Mineral Gray      Qualcomm Snapdragon 680
# 3                 POCO C50      Royal Blue           Mediatek Helio A22
# 4          Infinix HOT 30i        Marigold                          G37
# ..                     ...             ...                          ...
# 536  SAMSUNG Galaxy S23 5G           Cream  Qualcomm Snapdragon 8 Gen 2
# 537               LAVA Z21            Cyan                    Octa Core
# 538         Tecno Spark 8T  Turquoise Cyan           MediaTek Helio G35
# 539  SAMSUNG Galaxy A54 5G    Awesome Lime      Exynos 1380, Octa Core
# 540               OPPO A77        Sky Blue           Mediatek Helio G35
#
# [541 rows x 3 columns]

# %%
# we saparate all categorical columns to encode them

# %%
# to check the numeric column
numeric_columns = dataset.select_dtypes(include=['number']).columns

print(dataset[numeric_columns])
# Out:
#      Memory  RAM  Battery_  Rear Camera  Front Camera  AI Lens  Mobile Height  \
# 0        64    4      6000         13.0           5.0        1          16.76
# 1        64    4      6000         13.0           5.0        1          16.76
# 2       128    8      5000         50.0          16.0        0          16.64
# 3        32    2      5000          8.0           5.0        0          16.56
# 4       128    8      5000         50.0           5.0        1          16.76
# ..      ...  ...       ...          ...           ...      ...            ...
# 536     256    8      3900         50.0          12.0        0          15.49
# 537      32    2      3100          5.0           2.0        0          12.70
# 538      64    4      5000         50.0           8.0        0          16.76
# 539     128    8      5000         50.0          32.0        0          16.26
# 540     128    4      5000         50.0           8.0        0          16.66
#
#        Prize
# 0     7299.0
# ...

# %%
#to visiualize the relationship between prize and colour
lineplot = sns.lineplot(x='Processor_', y='Prize', data=dataset)
plt.title('Line Plot of Colour vs Prize')
plt.show()

# %% [markdown]
# Fluctuation in Prize Values: The prize values vary significantly, ranging from near 0 to about 80,000.
# There are sharp peaks and valleys, indicating variability in prize values for different colors.

# %%
# to visiualize the relationship between prize and Processor

lineplot = sns.lineplot(x='Processor_', y='Prize', data=dataset)
plt.title('Line Plot of Processor_ vs Prize')
# Out:
# Text(0.5, 1.0, 'Line Plot of Processor_ vs Prize')

# %% [markdown]
# The graph is a line plot of "Processor_" vs. "Prize", showing how the prize values vary with different processors. This indicates a wide price range for devices with different processors.

# %%
# to visiualize the relationship between prize and Model

lineplot = sns.lineplot(x='Model', y='Prize', data=dataset)
plt.title('Line Plot of Model vs Prize')
# Out:
# Text(0.5, 1.0, 'Line Plot of Model vs Prize')

# %% [markdown]
# The graph is a line plot of "Model" vs. "Prize", showing how prize values vary across different models.Prize values vary between 0 and approximately 80,000, indicating that the models cover a wide range of pricing categories (from low to high).
# The graph represents a relationship between "Model" and "Prize", which seems to suggest a non-linear and inconsistent relationship.

# %%
# to visiualize the relationship between Rear Camera and Model

lineplot = sns.lineplot(x='Rear Camera', y='Prize', data=dataset)
plt.title('Line Plot of Rear Camera vs Prize')
# Out:
# Text(0.5, 1.0, 'Line Plot of Rear Camera vs Prize')

# %% [markdown]
# The graph is a line plot of "Rear camera_" vs. "Prize", showing how the prize values vary with different processors. This indicates a wide price range for devices with different Rear camera.

# %%
 #to visiualize the relationship between Front Camera and Model

lineplot = sns.lineplot(x='Front Camera', y='Prize', data=dataset)
plt.title('Line Plot of Front Camera vs Prize')
# Out:
# Text(0.5, 1.0, 'Line Plot of Front Camera vs Prize')

# %%
numeric_columns = dataset.select_dtypes(include=['number'])
numeric_columns
# Out:
#      Memory  RAM  Battery_  Rear Camera  Front Camera  AI Lens  Mobile Height  \
# 0        64    4      6000         13.0           5.0        1          16.76
# 1        64    4      6000         13.0           5.0        1          16.76
# 2       128    8      5000         50.0          16.0        0          16.64
# 3        32    2      5000          8.0           5.0        0          16.56
# 4       128    8      5000         50.0           5.0        1          16.76
# ..      ...  ...       ...          ...           ...      ...            ...
# 536     256    8      3900         50.0          12.0        0          15.49
# 537      32    2      3100          5.0           2.0        0          12.70
# 538      64    4      5000         50.0           8.0        0          16.76
# 539     128    8      5000         50.0          32.0        0          16.26
# 540     128    4      5000         50.0           8.0        0          16.66
#
#        Prize
# 0     7299.0
# ...

# %%
#correlation_matrix

correlation_matrix = numeric_columns.corr()
correlation_matrix
# Out:
#                  Memory       RAM  Battery_  Rear Camera  Front Camera  \
# Memory         1.000000  0.625284 -0.053210     0.530615      0.496865
# RAM            0.625284  1.000000 -0.104923     0.439558      0.493861
# Battery_      -0.053210 -0.104923  1.000000     0.198260      0.032970
# Rear Camera    0.530615  0.439558  0.198260     1.000000      0.505378
# Front Camera   0.496865  0.493861  0.032970     0.505378      1.000000
# AI Lens       -0.094442 -0.082622  0.150156    -0.043597     -0.111779
# Mobile Height  0.063163  0.092951  0.695641     0.239883      0.208012
# Prize          0.566660  0.532024 -0.034297     0.410367      0.532321
#
#                 AI Lens  Mobile Height     Prize
# Memory        -0.094442       0.063163  0.566660
# RAM           -0.082622       0.092951  0.532024
# Battery_       0.150156       0.695641 -0.034297
# Rear Camera   -0.043597       0.239883  0.410367
# Front Camera  -0.111779       0.208012  0.532321
# ...

# %%
# Plot a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f',square=True)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Insights of  Correlations:
#
# Memory and Price (0.57):Positive correlation: Higher memory typically contributes to a higher price.
#
# RAM and Price (0.53):Positive correlation: More RAM generally leads to a higher price.
#
# Front Camera and Price (0.53):Positive correlation: Better front cameras are often associated with more expensive devices.
#
# Rear Camera and Price (0.41):Moderate positive correlation: Rear camera quality also plays a role in pricing but is less influential than front cameras.
#
# Battery and Price (-0.03):Almost no correlation: Battery capacity doesn't significantly affect the price.
#
# AI Lens and Price (-0.15):Weak negative correlation: AI lens presence may be more common in lower-priced models.
#
# Mobile Height and Price (0.18):Weak positive correlation: Larger mobile height could have a slight effect on pricing.
#
#
# Battery Capacity -Although important for users, battery size doesn't strongly influence price, indicating it might not be a primary focus for premium models.

# %%
# finding outlier

# %%
#outlier_values

# Identify outliers using the IQR method
numeric_columns = dataset.select_dtypes(include=['number']).columns

outliers_iqr = {}
for col in numeric_columns:
    Q1 = dataset[col].quantile(0.25)
    Q3 = dataset[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Find outliers
    outliers = dataset[(dataset[col] < lower_bound) | (dataset[col] > upper_bound)]
    outliers_iqr[col] = outliers[col].tolist()

print("Outliers using IQR Method:")
for col, outlier_values in outliers_iqr.items():
    print(f"{col}: {outlier_values}")
# Out:
# Outliers using IQR Method:
# Memory: [256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256, 256]
# RAM: []
# ...

# %%
#Plotting
plt.figure(figsize=(3, 2))
sns.boxplot(dataset['Prize'], orient='h', color='skyblue')
plt.title('Boxplot to Detect Outliers')
plt.show()

# %%
# Function to handle outliers using IQR
def handle_outliers(dataset, columns, method="cap"):

    for col in columns:
        # Calculate Q1, Q3, and IQR
        Q1 = dataset[col].quantile(0.25)
        Q3 = dataset[col].quantile(0.75)
        IQR = Q3 - Q1

        # Define lower and upper bounds for outliers
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        if method == "remove":
            # Remove rows with outliers
            dataset = dataset[(dataset[col] >= lower_bound) & (dataset[col] <= upper_bound)]
        elif method == "cap":
            # Cap outliers to the nearest boundary
            dataset[col] = dataset[col].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

    return dataset

# %%
dataset
# Out:
#                      Model          Colour  Memory  RAM  Battery_  \
# 0          Infinix SMART 7     Night Black      64    4      6000
# 1          Infinix SMART 7      Azure Blue      64    4      6000
# 2             MOTOROLA G32    Mineral Gray     128    8      5000
# 3                 POCO C50      Royal Blue      32    2      5000
# 4          Infinix HOT 30i        Marigold     128    8      5000
# ..                     ...             ...     ...  ...       ...
# 536  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537               LAVA Z21            Cyan      32    2      3100
# 538         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540               OPPO A77        Sky Blue     128    4      5000
#
#      Rear Camera  Front Camera  AI Lens  Mobile Height  \
# 0           13.0           5.0        1          16.76
# 1           13.0           5.0        1          16.76
# ...

# %%
# Choose method: "remove" or "cap"
cleaned_data = handle_outliers(dataset, numeric_columns, method="cap")

# Display summary of cleaned data
print(cleaned_data.describe())
# Out:
#            Memory         RAM  Battery_  Rear Camera  Front Camera  AI Lens  \
# count  541.000000  541.000000     541.0   541.000000    541.000000    541.0
# mean   107.297597    5.397412    5000.0    44.570240     11.520333      0.0
# std     53.085066    1.984923       0.0    25.667887      7.230437      0.0
# min     16.000000    2.000000    5000.0     0.000000      0.000000      0.0
# 25%     64.000000    4.000000    5000.0    13.000000      5.000000      0.0
# 50%    128.000000    6.000000    5000.0    50.000000      8.000000      0.0
# 75%    128.000000    8.000000    5000.0    50.000000     16.000000      0.0
# max    224.000000    8.000000    5000.0   105.500000     32.500000      0.0
#
#        Mobile Height         Prize
# count     541.000000    541.000000
# mean       16.675869  15499.798521
# std         0.316393   8234.745675
# min        15.865000    920.000000
# 25%        16.510000   9290.000000
# 50%        16.710000  13499.000000
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Encode the processor names to numeric values
label_encoder = LabelEncoder()
dataset['Processor_Encoded'] = label_encoder.fit_transform(dataset['Processor_'])
dataset['Colour_Encoded'] = label_encoder.fit_transform(dataset['Colour'])
dataset['Model_Encoded'] = label_encoder.fit_transform(dataset['Model'])
dataset['Model_Encoded']
# Out:
# 0       23
# 1       23
# 2       37
# 3       69
# 4       12
#       ...
# 536    118
# 537     32
# 538    123
# 539    110
# 540     59
# Name: Model_Encoded, Length: 541, dtype: int64

# %%
def Prize_range(prize):
    if prize < 20000:
        return 'Low'
    elif 20000 <= prize <= 40000:
        return 'Medium'
    else:
        return 'High'

# %%
# Apply the Prize_range function to the Prize column
dataset['Prize_range'] = dataset['Prize'].apply(Prize_range)

# Display the Model and Prize_range
print(dataset[['Model', 'Prize', 'Prize_range']])
# Out:
#                      Model    Prize Prize_range
# 0          Infinix SMART 7   7299.0         Low
# 1          Infinix SMART 7   7299.0         Low
# 2             MOTOROLA G32  11999.0         Low
# 3                 POCO C50   5649.0         Low
# 4          Infinix HOT 30i   8999.0         Low
# ..                     ...      ...         ...
# 536  SAMSUNG Galaxy S23 5G  34265.0      Medium
# 537               LAVA Z21   5998.0         Low
# 538         Tecno Spark 8T   9990.0         Low
# 539  SAMSUNG Galaxy A54 5G  34265.0      Medium
# 540               OPPO A77  15999.0         Low
#
# [541 rows x 3 columns]

# %%
#pie chart of model and prize Range
plt.pie(dataset['Prize_range'].value_counts(), labels=dataset['Prize_range'].unique(), autopct='%1.1f%%')
plt.title('Distribution of Models by Prize Range')
plt.show()

# %%
print(dataset['Prize_range'].unique())
# Out:
# ['Low' 'Medium']

# %%
 #Filter datasets

high_priced_models = dataset[dataset['Prize_range'] =='High']
medium_priced_models = dataset[dataset['Prize_range'] =='Medium']
low_priced_models = dataset[dataset['Prize_range'] =='Low']

# # Display
 print("High Priced Models:\n", high_priced_models[['Model', 'Prize']])
 print("\nMedium Priced Models:\n", medium_priced_models[['Model', 'Prize']])
 print("\nLow Priced Models:\n", low_priced_models[['Model', 'Prize']])
# Out:
# High Priced Models:
#  Empty DataFrame
# Columns: [Model, Prize]
# Index: []
#
# Medium Priced Models:
#                       Model    Prize
# 50              vivo T2 5G  20999.0
# 51              vivo T2 5G  20999.0
# 117       MOTOROLA Edge 40  29999.0
# 135        Google Pixel 6a  28999.0
# 136        Google Pixel 6a  28999.0
# ..                     ...      ...
# 527           vivo Y100 5G  23999.0
# 531          OPPO F21s Pro  20890.0
# 532        APPLE iPhone 12  34265.0
# 536  SAMSUNG Galaxy S23 5G  34265.0
# 539  SAMSUNG Galaxy A54 5G  34265.0
#
# [124 rows x 2 columns]
#
# Low Priced Models:
#                     Model    Prize
# 0        Infinix SMART 7   7299.0
# 1        Infinix SMART 7   7299.0
# 2           MOTOROLA G32  11999.0
# 3               POCO C50   5649.0
# 4        Infinix HOT 30i   8999.0
# ..                   ...      ...
# 534       Nokia G11 Plus   9790.0
# 535  SAMSUNG Galaxy A04e   9999.0
# 537             LAVA Z21   5998.0
# ...

# %%
#data standerdation and normalization
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import MinMaxScaler

# %%
scaler = StandardScaler()
standardized_data = scaler.fit_transform(dataset[numeric_columns])
standardized_data
# Out:
# array([[-0.81638156, -0.70466488,  0.        , ...,  0.        ,
#          0.26615313, -0.99679925],
#        [-0.81638156, -0.70466488,  0.        , ...,  0.        ,
#          0.26615313, -0.99679925],
#        [ 0.39034637,  1.31239173,  0.        , ...,  0.        ,
#         -0.11347252, -0.42551873],
#        ...,
#        [-0.81638156, -0.70466488,  0.        , ...,  0.        ,
#          0.26615313, -0.66971077],
#        [ 0.39034637,  1.31239173,  0.        , ...,  0.        ,
#         -1.31562041,  2.28089238],
#        [ 0.39034637, -0.70466488,  0.        , ...,  0.        ,
#         -0.05020157,  0.06067746]])

# %%
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(dataset[numeric_columns])
normalized_data
# Out:
# array([[0.23076923, 0.33333333, 0.        , ..., 0.        , 0.52034884,
#         0.19130304],
#        [0.23076923, 0.33333333, 0.        , ..., 0.        , 0.52034884,
#         0.19130304],
#        [0.53846154, 1.        , 0.        , ..., 0.        , 0.4505814 ,
#         0.33225371],
#        ...,
#        [0.23076923, 0.33333333, 0.        , ..., 0.        , 0.52034884,
#         0.2720048 ],
#        [0.53846154, 1.        , 0.        , ..., 0.        , 0.22965116,
#         1.        ],
#        [0.53846154, 0.33333333, 0.        , ..., 0.        , 0.4622093 ,
#         0.45221173]])

# %%
normalized_dataset = pd.DataFrame(normalized_data, columns=numeric_columns)
print(normalized_dataset)
# Out:
#        Memory       RAM  Battery_  Rear Camera  Front Camera  AI Lens  \
# 0    0.230769  0.333333       0.0     0.123223      0.153846      0.0
# 1    0.230769  0.333333       0.0     0.123223      0.153846      0.0
# 2    0.538462  1.000000       0.0     0.473934      0.492308      0.0
# 3    0.076923  0.000000       0.0     0.075829      0.153846      0.0
# 4    0.538462  1.000000       0.0     0.473934      0.153846      0.0
# ..        ...       ...       ...          ...           ...      ...
# 536  1.000000  1.000000       0.0     0.473934      0.369231      0.0
# 537  0.076923  0.000000       0.0     0.047393      0.061538      0.0
# 538  0.230769  0.333333       0.0     0.473934      0.246154      0.0
# 539  0.538462  1.000000       0.0     0.473934      0.984615      0.0
# 540  0.538462  0.333333       0.0     0.473934      0.246154      0.0
#
#      Mobile Height     Prize
# 0         0.520349  0.191303
# 1         0.520349  0.191303
# 2         0.450581  0.332254
# ...

# %%
# split test and test data

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score,mean_squared_error

# %%
# Split data before creating new encoded features
x= dataset[['Colour_Encoded', 'Memory', 'RAM', 'Battery_',
       'Rear Camera', 'Front Camera', 'AI Lens', 'Mobile Height','Processor_Encoded','Model_Encoded']]
y = dataset['Prize']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Train model
model = RandomForestRegressor()
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# model prediction
y_pred = model.predict(x_test)

# %%
# Evaluate model and find the accuracy

print("MAE:", mean_absolute_error(y_test, y_pred))
print("R²:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# MAE: 1359.0175458715594
# R²: 0.8836988337514379
# MSE: 6788165.463940194

# %%
#Training score
print("Training Score:", model.score(x_train, y_train))
# Out:
# Training Score: 0.9877305645023591

# %%
#testing score
print("Testing Score:", model.score(x_test, y_test))
# Out:
# Testing Score: 0.8836988337514379

# %%
#Recursive Feature Elimination (RFE)=Recursive Feature Elimination (RFE) is a feature selection technique used to select the most important features in a dataset for building a machine learning model. The goal is to improve the model’s performance and reduce overfitting by removing less important features.
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

# Define the model
model = RandomForestRegressor()

# Perform RFE
rfe = RFE(estimator=model, n_features_to_select=5)
rfe.fit(x, y)

# Get selected features
selected_features = x.columns[rfe.support_]
print("Selected Features:", selected_features)
# Out:
# Selected Features: Index(['Memory', 'Rear Camera', 'Front Camera', 'Processor_Encoded',
#        'Model_Encoded'],
#       dtype='object')

# %%
# Mutual Information Scores--Measures the dependency between each feature and the target variable.
from sklearn.feature_selection import mutual_info_regression

# Calculate mutual information scores
mutual_info = mutual_info_regression
mutual_info = mutual_info(x, y)
mutual_info
#After performing these analyses we have retain the most relevant features for modeling
# Out:
# array([0.07465562, 0.70294829, 0.67396986, 0.02042871, 0.7285546 ,
#        0.84381091, 0.        , 0.77587124, 1.12179807, 1.07783698])

# %%
from sklearn.ensemble import RandomForestRegressor

model.fit(x, y)

# Extract feature importance scores
feature_importances = model.feature_importances_

# Create a DataFrame for easy interpretation
importance_df = pd.DataFrame({'Feature': x.columns,'Importance': feature_importances}).sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
#              Feature  Importance
# 5       Front Camera    0.528896
# 9      Model_Encoded    0.156328
# 1             Memory    0.096941
# 8  Processor_Encoded    0.063904
# 4        Rear Camera    0.056928
# 2                RAM    0.052059
# 0     Colour_Encoded    0.026724
# 7      Mobile Height    0.018220
# 3           Battery_    0.000000
# 6            AI Lens    0.000000

# %%
import matplotlib.pyplot as plt

# Plot feature importance
plt.figure(figsize=(6, 3))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.title("Feature Importance")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# Details of the above visualization:
#
#
#
# *   Front Camera has the highest importance score, indicating it's the most influential feature.
#
# *   Memory has moderate importance.
#
# *  Features like Colour_Encoded, Mobile Height, Rear Camera, RAM,  have lower importance scores, suggesting they contribute less to the model's predictions.
#
#
#
#
#
# .

# %%
#Lasso Regression Example for Actual and Predicted Prices:
from sklearn.linear_model import Lasso

# Initialize the Lasso regression model
lasso = Lasso(alpha=0.1)

# Fit the model
lasso.fit(x_train, y_train)

# Make predictions on the test set
y_pred = lasso.predict(x_test)

# Print the actual and predicted prices
actual_vs_predicted = pd.DataFrame({'Actual Price': y_test, 'Predicted Price': y_pred})

print(actual_vs_predicted.head(20))  # Display the first few rows of actual and predicted prices
# Out:
#      Actual Price  Predicted Price
# 229        8499.0     10266.181979
# 73         6299.0      5621.579170
# 352       19499.0     21081.297803
# 86        10999.0      9987.608311
# 470       12599.0     13338.157553
# 77        14499.0     15620.646614
# 297        9999.0      9068.212800
# 468       17999.0     17171.045291
# 342       29499.0     20665.578134
# 384        9790.0      8218.015542
# 6          8999.0     15979.939638
# 117       29999.0     34218.283590
# 411       19499.0     21081.427569
# 75        16499.0     20679.488388
# 272       32999.0     23537.186534
# 195       16999.0     14968.354911
# 485        9999.0     12972.830259
# 101       15999.0     20980.401569
# 527       23999.0     20786.360022
# 55        18999.0     19059.195062

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Calculate MSE and R^2
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 17537724.515020058
# R-squared: 0.6995273869975893

# %%
# Get the coefficients and corresponding feature names
coefficients = lasso.coef_
feature_names = x_train.columns  # Get feature names from the training data

# Create a DataFrame to view feature importance
feature_importance = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients,
    'Absolute Coefficient': np.abs(coefficients)
})
# Sort by the absolute value of coefficients to identify the most influential features
feature_importance = feature_importance.sort_values(by='Absolute Coefficient', ascending=False)

print("Most Influential Features in Pricing:")
print(feature_importance)
# Out:
# Most Influential Features in Pricing:
#              Feature  Coefficient  Absolute Coefficient
# 7      Mobile Height  -858.952831            858.952831
# 2                RAM   721.285042            721.285042
# 5       Front Camera   496.256127            496.256127
# 1             Memory    51.908091             51.908091
# 4        Rear Camera    15.383033             15.383033
# 9      Model_Encoded    -8.860863              8.860863
# 8  Processor_Encoded     2.907693              2.907693
# 0     Colour_Encoded     0.129765              0.129765
# 3           Battery_     0.000000              0.000000
# 6            AI Lens     0.000000              0.000000

# %% [markdown]
# \Here we have found that strong influencer is RAM and Front camera.
# The mobile price will be more influnece by these features.

# %%
#A coefficient (also called a weight) is a number that represents the strength and direction
 #of the relationship between a feature and the target variable in a regression model.


 #In the context of regression models, the absolute coefficient tells you the magnitude of the relationship between the feature and
 #the target variable, without considering the direction (whether the feature increases or decreases the target).

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


top_n = 10
avg_prices = dataset.groupby('Model')['Prize'].mean().reset_index().nlargest(top_n,'Prize')

plt.figure(figsize=(6, 4))
sns.set_style('whitegrid')

cmap = plt.get_cmap('viridis')
colors = [cmap(i) for i in np.linspace(0.5,0.9,len(avg_prices))]

sns.barplot(x='Model', y='Prize',hue="Model", data=avg_prices, palette=colors,legend=False)
plt.xlabel('Model',fontsize=6)
plt.ylabel('Average Prize',fontsize=6)
plt.title('Top {} Models by Average Prize'.format(top_n), fontsize=6)
plt.xticks(rotation=90,fontsize=6)
plt.tight_layout()
plt.show()

# %%
top_10_mobiles = dataset.sort_values(by='Prize').head(10)

# %%
# Price vs. RAM, memory, and battery.Scatter Plots
fig, axes = plt.subplots(1, 3, figsize=(10, 5))
sns.scatterplot(data=dataset, x='RAM', y='Prize', ax=axes[0], hue='RAM', palette='viridis', s=100)
sns.scatterplot(data=dataset, x='Memory', y='Prize', ax=axes[1], hue='Memory', palette='viridis', s=100)
sns.scatterplot(data=dataset, x='Battery_', y='Prize', ax=axes[2], hue='Battery_', palette='viridis', s=100)
plt.tight_layout()

# %% [markdown]
# Price vs. RAM: Shows the price trend as RAM increases, with higher RAM associated with higher prices.
#
# Price vs. Memory: Indicates a positive correlation between internal memory and price.
#
#
# Price vs. Battery: Displays minimal impact of battery capacity on pricing

# %%
#Bar Plot: Top 10 Processors
fig, ax = plt.subplots(figsize=(7, 3))
top_processors = dataset['Processor_'].value_counts().head(10)
sns.barplot(x=top_processors.values, y=top_processors.index, palette='coolwarm', ax=ax)
plt.title("Top 10 Processors")
# Out:
# <ipython-input-71-9e1e2895a504>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_processors.values, y=top_processors.index, palette='coolwarm', ax=ax)
# Text(0.5, 1.0, 'Top 10 Processors')

# %% [markdown]
# Top 10 Processors: It is most frequent used processors, such as Qualcomm Snapdragon 680 and Unisoc T612.

# %%
#highest color selling mobile as yellow with 12 counts.
dataset['Colour'].value_counts()
# Out:
# Colour
# Yellow            12
# Royal Blue         8
# Power Black        8
# Black              8
# Midnight Black     7
#                   ..
# Polar Blue         1
# Cosmic grey        1
# Sea                1
# Infinity Black     1
# Sky Blue           1
# Name: count, Length: 275, dtype: int64

# %%
dataset['Model'].value_counts()
# Out:
# Model
# vivo Y16                 9
# realme C55               9
# SAMSUNG Galaxy A14 5G    9
# REDMI Note 12 Pro 5G     9
# vivo T1 44W              8
#                         ..
# vivo Y1s                 1
# OnePlus Nord             1
# Micromax 3               1
# vivo Y33s                1
# OPPO A77                 1
# Name: count, Length: 187, dtype: int64

# %%
dataset[['Model','Prize']].value_counts()
# Out:
# Model                     Prize
# REDMI 10                  9499.0     5
# Infinix HOT 30i           8999.0     4
# SAMSUNG Galaxy F14 5G     13490.0    4
#                           14490.0    4
# vivo Y100 5G              23999.0    4
#                                     ..
# SAMSUNG Galaxy A13        16499.0    1
# SAMSUNG Galaxy M04        7961.0     1
#                           9104.0     1
# SAMSUNG Galaxy S21 FE 5G  32999.0    1
# vivo Y75                  19990.0    1
# Name: count, Length: 303, dtype: int64

# %% [markdown]
# For the above details ,out of them REDME 10 has highest selling of records.
